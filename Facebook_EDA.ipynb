# %% [markdown]
# # Facebook EDA

# %%
import pandas as pd

# %%
facebook_post_df = pd.read_csv('/Users/scottcambo/Downloads/Facebook Insights Data Export (Post Level) - OTV - Open Television - 2020-01-10.csv',skiprows=[1]).fillna(0)

# %%
facebook_post_df.head()
# Out:
#                             Post ID  \
# 0  357045034501999_1018934711646358
# 1  357045034501999_1018273905045772
# 2  357045034501999_1015508565322306
# 3  357045034501999_1015338848672611
# 4  357045034501999_1014672062072623
#
#                                            Permalink  \
# 0  https://www.facebook.com/weareotv/posts/101893...
# 1  https://www.facebook.com/weareotv/posts/101827...
# 2  https://www.facebook.com/weareotv/posts/101550...
# 3  https://www.facebook.com/weareotv/posts/101533...
# 4  https://www.facebook.com/weareotv/posts/101467...
#
#                                         Post Message   Type  Countries  \
# 0  OTV - Open Television updated their phone number.   Link        0.0
# 1  OTV Presents: Renee, Good Enough &amp; Kings a...  Photo        0.0
# 2                                                🔥🔥🔥   Link        0.0
# 3              OTV presents: Low Strung and Border'd  Photo        0.0
# ...
